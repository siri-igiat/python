# %%
from matplotlib import pyplot as p

# %%
import numpy as np

# %%
a=np.array([[1,2,3],[4,5,6]])

# %%
a
# Out:
# array([[1, 2, 3],
#        [6, 4, 5]])

# %%
p.plot(a)

# %%
x=np.array([1,2,3])
y=np.array([4,6,7])

# %%
p.plot(x,y)
